# %% [markdown]
# # Statistical analysis of NYC Taxi Fare Dataset

# %% [markdown]
# ![signature.png](data:image/png;base64,...)

# %% [markdown]
# # Table of Contents

# %% [markdown]
# 1.   [Introduction and Sampling and validity](http://localhost:8888/notebooks/mini-project%2FIntroduction%20and%20Sampling%20and%20validity.ipynb?)
# 2.   [Data Preparation](http://localhost:8888/notebooks/mini-project/Data_Preparation.ipynb?)
# 3.   [Data Description](http://localhost:8888/notebooks/mini-project/Data%20Description.ipynb?)
# 4.   [Relationship Tests](http://localhost:8888/notebooks/mini-project/Relationship%20Tests.ipynb?)
# 5.   [Bootstrapping](http://localhost:8888/notebooks/mini-project%2FBootstrapping.ipynb)
# 6.   [Bayesian_Methods](http://localhost:8888/notebooks/mini-project%2FBayesian_Methods.ipynb)
# 7.   [Conclusions](http://localhost:8888/notebooks/mini-project/Conclusion.ipynb?)
# 10.  [References](http://localhost:8888/notebooks/mini-project/References.ipynb)
